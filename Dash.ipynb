# %% [markdown]
# <a href="https://colab.research.google.com/github/Astmatik001/MEVD004/blob/main/Dash.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
# !pip install dash
# !pip install dash-mantine-components
# !pip install pyngrok
# !pip install opendatasets

# %%
import opendatasets as od

dataset_url = 'https://www.kaggle.com/datasets/solomonameh/spotify-music-dataset'
od.download(dataset_url)
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username:   elibooba
# Your Kaggle Key: ··········
# Dataset URL: https://www.kaggle.com/datasets/solomonameh/spotify-music-dataset
# Downloading spotify-music-dataset.zip to ./spotify-music-dataset
# 100%|██████████| 573k/573k [00:00<00:00, 594MB/s]

# %%
import pandas as pd
df = pd.read_csv('/content/spotify-music-dataset/high_popularity_spotify_data.csv')

# %%
import dash
from dash import dcc, html
import plotly.express as px
import pandas as pd

df = pd.read_csv('high_popularity_spotify_data.csv')
data = df.copy()

data['track_album_release_date'] = pd.to_datetime(
    data['track_album_release_date'],
    errors='coerce'
)
data['year'] = data['track_album_release_date'].dt.year
data['duration_min'] = data['duration_ms'] / 60000

fig_genre = px.box(
    data,
    x='playlist_genre',
    y='track_popularity',
    title='Популярность треков по жанрам'
)

fig_energy = px.scatter(
    data,
    x='energy',
    y='track_popularity',
    opacity=0.5,
    title='Связь энергии и популярности'
)

fig_duration = px.scatter(
    data,
    x='duration_min',
    y='track_popularity',
    opacity=0.5,
    title='Связь длины и популярности'
)

app = dash.Dash(__name__)

app.layout = html.Div(
    style={'padding': '20px'},
    children=[
        html.H1('Музыкальные треки и популярность'),

        dcc.Graph(figure=fig_genre),
        dcc.Graph(figure=fig_energy),
        dcc.Graph(figure=fig_duration)
    ]
)

if __name__ == '__main__':
    app.run(debug=True)
# Out:
# ERROR:pyngrok.process.ngrok:t=2026-01-12T14:27:46+0000 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="authentication failed: Usage of ngrok requires a verified account and authtoken.\n\nSign up for an account: https://dashboard.ngrok.com/signup\nInstall your authtoken: https://dashboard.ngrok.com/get-started/your-authtoken\r\n\r\nERR_NGROK_4018\r\n"
# ---------------------------------------------------------------------------
# PyngrokNgrokError                         Traceback (most recent call last)
# /tmp/ipython-input-2340048285.py in <cell line: 0>()
#      26
#      27 # Ngrok для внешнего доступа
# ---> 28 public_url = ngrok.connect(8050)
#      29 print(f"Открыть дашборд по ссылке: {public_url}")
#      30
#
# /usr/local/lib/python3.12/dist-packages/pyngrok/ngrok.py in connect(addr, proto, name, pyngrok_config, **options)
#     333     logger.info(f"Opening tunnel named: {name}")
#     334
# --> 335     api_url = get_ngrok_process(pyngrok_config).api_url
#     336
#     337     logger.debug(f"Creating tunnel with options: {options}")
#
# /usr/local/lib/python3.12/dist-packages/pyngrok/ngrok.py in get_ngrok_process(pyngrok_config)
#     200     install_ngrok(pyngrok_config)
#     201
# --> 202     return process.get_process(pyngrok_config)
#     203
#     204
#
# /usr/local/lib/python3.12/dist-packages/pyngrok/process.py in get_process(pyngrok_config)
#     269         return _current_processes[pyngrok_config.ngrok_path]
#     270
# --> 271     return _start_process(pyngrok_config)
#     272
#     273
#
# /usr/local/lib/python3.12/dist-packages/pyngrok/process.py in _start_process(pyngrok_config)
#     445
#     446         if ngrok_process.startup_error is not None:
# --> 447             raise PyngrokNgrokError(f"The ngrok process errored on start: {ngrok_process.startup_error}.",
#     448                                     ngrok_process.logs,
#     449                                     ngrok_process.startup_error)
#
# PyngrokNgrokError: The ngrok process errored on start: authentication failed: Usage of ngrok requires a verified account and authtoken.\n\nSign up for an account: https://dashboard.ngrok.com/signup\nInstall your authtoken: https://dashboard.ngrok.com/get-started/your-authtoken\r\n\r\nERR_NGROK_4018\r\n.
